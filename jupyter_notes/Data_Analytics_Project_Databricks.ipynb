# %%
import findspark
findspark.init('/usr/local/spark/spark-2.4.0-bin-hadoop2.7')
import pyspark

# Create Optimus Context
#from optimus import Optimus
#op = Optimus(master="local", app_name = "DataProfiler" , checkpoint= True, queue_url=None)
# Import pyspark session and others
from pyspark import SQLContext
from pyspark.sql.session import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, BooleanType, IntegerType, ArrayType

import spark_df_profiling

sc = pyspark.SparkContext(appName = 'test')
sqlContext = SQLContext(sc)

# %%
df = sqlContext.read.csv("../datasets/Kenya_Log.csv",header=True)
df.show()
df_spark = df.cache()
# Out:
# +---+---------+-------+-----+--------------------+------+-------+-----------+----------+--------+----------+------+--------+
# | ID|     Date|Country|VehID|         Destination|KmInit|KmFinal| FuelBought|AmountFuel|CashFuel|AmountCash|FuelKm|DriverID|
# +---+---------+-------+-----+--------------------+------+-------+-----------+----------+--------+----------+------+--------+
# | 30|1/11/2008|  Kenya|   12|  Nairobi - Amboseli| 67029|  67429|          0|         0|       0|         0|     0|       1|
# | 31|1/14/2008|  Kenya|   12|     Tsavo - Nairobi| 67429|  67848|          0|         0|       0|         0|     0|       1|
# | 32|1/14/2008|  Kenya|   12|CRS - Westlands -...| 67848|  67850|          0|         0|       0|         0|     0|       1|
# | 33|1/17/2008|  Kenya|   12|Nairobi - Machako...| 67850|  68072|          0|         0|       0|         0|     0|       1|
# ...

# %%
spark_df_profiling.ProfileReport(df_spark)
# Out:
# <meta charset="UTF-8">
#
# <style>
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 1em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#         .ignore {
#             opacity: 0.4;
#         }
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#         .col-md-12 {
#             padding-left: 2em;
#         }
#         .indent {
#             margin-left: 1em;
#         }
# ...
